# %%
from ultralytics import YOLO
from pathlib import Path

# %%
model = YOLO('../data/model.pt')

# %%
results = model.predict(
    source='../data/test_images',          
    conf=0.4
    )
# Out:
# image 1/6 c:\Users\HP\OneDrive - University of Moratuwa\Desktop\ML-Project\Construction-Safety-Monitor\notebooks\..\data\test_images\image_1.jpg: 448x640 1 Gloves, 1 Hardhat, 1 NO-Mask, 1 Person, 432.9ms
# image 2/6 c:\Users\HP\OneDrive - University of Moratuwa\Desktop\ML-Project\Construction-Safety-Monitor\notebooks\..\data\test_images\image_2.jpg: 480x640 1 NO-Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 393.5ms
# image 3/6 c:\Users\HP\OneDrive - University of Moratuwa\Desktop\ML-Project\Construction-Safety-Monitor\notebooks\..\data\test_images\image_3.jpg: 448x640 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 349.1ms
# image 4/6 c:\Users\HP\OneDrive - University of Moratuwa\Desktop\ML-Project\Construction-Safety-Monitor\notebooks\..\data\test_images\image_5.jpg: 448x640 3 Hardhats, 1 NO-Hardhat, 2 NO-Masks, 3 NO-Safety Vests, 4 Persons, 338.5ms
# image 5/6 c:\Users\HP\OneDrive - University of Moratuwa\Desktop\ML-Project\Construction-Safety-Monitor\notebooks\..\data\test_images\image_6.jpg: 480x640 (no detections), 365.2ms
# image 6/6 c:\Users\HP\OneDrive - University of Moratuwa\Desktop\ML-Project\Construction-Safety-Monitor\notebooks\..\data\test_images\imgae_7.jpg: 384x640 3 Hardhats, 2 NO-Masks, 3 NO-Safety Vests, 2 Persons, 302.8ms
# Speed: 1.6ms preprocess, 363.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
output_folder = Path("test_detections")
output_folder.mkdir(parents=True, exist_ok=True)

for i, results in enumerate(results):
    # Save each image with detections
    save_path = output_folder / f"detected_{i:04d}.jpg"
    results.save(filename=str(save_path))
    print(f"Saved: {save_path.name}")
# Out:
# Saved: detected_0000.jpg
# Saved: detected_0001.jpg
# Saved: detected_0002.jpg
# Saved: detected_0003.jpg
# Saved: detected_0004.jpg
# Saved: detected_0005.jpg

# %%
from IPython.display import Image, display
import glob

for img_path in sorted(glob.glob("test_detections/*.jpg"))[:8]:
    display(Image(filename=img_path, width=700))
